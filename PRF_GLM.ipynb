# %% [raw]
# General Linear Model
# --------------------

# %% [raw]
# This is Python, so let's start with importing some modules:

# %%
import os
import numpy as np
import scipy as sp
import scipy.stats as stats
import scipy.signal as signal
import matplotlib.pyplot as plt
from sympy import *
import math

# %% [raw]
# Let's do inline plotting:

# %%
# %matplotlib inline

# %% [raw]
# Let's first create and plot the true pupil response to a transient input. This is called an "Inpulse Response Function" (IRF).

# %%
# define an Impulse Response Function:
def pupil_IRF(timepoints, s=1.0/(10**26), n=10.1, tmax=0.93):
    
    """ pupil_IRF defines the IRF (response to a transient input) of the pupil.
    
    Parameters
    ----------
    t: IRF is defined with respect to 't'
    s: scaling factor
    n: sets the width
    tmax: sets the time to peak 
    IRF_len: function is evaluated for t = [0:IRF_len]
    
    Returns
    -------
    y: IRF evaluated for t = [0:IRF_len]
    yprime: IRF first derivative evaluated for t = [0:IRF_len]
    
    """
    
    # in sympy:
    t = Symbol('t')
    y = ( (s) * (t**n) * (math.e**((-n*t)/tmax)) )
    yprime = y.diff(t)
    
    # lambdify:
    y = lambdify(t, y, "numpy")
    yprime = lambdify(t, yprime, "numpy")
    
    # evaluate:
    y = y(timepoints)
    yprime = yprime(timepoints)
    
    return (y, yprime)

# create the IRF:
sample_rate = 10
IRF_len = 3.0 # in seconds
timepoints = np.linspace(0,IRF_len,IRF_len*sample_rate)

IRF, IRF_prime = pupil_IRF(timepoints=timepoints)
IRF = IRF / IRF.std()
IRF_prime = IRF_prime / IRF_prime.std()

# plot the IRF:
fig = plt.figure()
plt.plot(timepoints, IRF, color='r')
# plt.plot(timepoints, IRF_prime, color='g')
plt.legend(['IRF'])
plt.title('Impulse Response Function')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# %% [raw]
# Let's simulate convolved timeseries data based on this IRF.

# %%
duration = 60 # in seconds
times_l = np.array([5,15,16,25])
times_r = np.array([35,45,46,55])
input_signal_l = np.zeros(duration * sample_rate)
input_signal_r = np.zeros(duration * sample_rate)
for i in times_l:
    input_signal_l[i*sample_rate] = 1
for i in times_r:
    input_signal_r[i*sample_rate] = 0.2
input_signal = input_signal_l + input_signal_r

# plot input:
timepoints = np.linspace(0, duration, duration*sample_rate)
fig = plt.figure()
plt.plot(timepoints, input_signal, 'r')
plt.legend(['"true" neural signal'], loc=1)
plt.title('"true" neural signal')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# convolve inputs with IRF:    
convolved_signal = (sp.convolve(input_signal, IRF, 'full'))[:-(IRF.shape[0]-1)]

# plot simulated convolved signal without noise:
fig = plt.figure()
plt.plot(timepoints, input_signal, 'r')
plt.plot(timepoints, convolved_signal)
plt.legend(['"true" neural signal', 'pupil time series'], loc=1)
plt.title('pupil time series, no noise')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# let's add some noise:
convolved_signal_noise = convolved_signal + np.random.normal(0,0.1,len(convolved_signal))

# plot simulated convolved signal with noise:
fig = plt.figure()
# plt.plot(timepoints, input_signal, 'r')
plt.plot(timepoints, convolved_signal_noise)
plt.legend(['BOLD time series'], loc=1)
for i in times_l:
    plt.axvline(i, color='r')
for i in times_r:
    plt.axvline(i, color='g')
# plt.legend(['"true" neural signal', 'pupil time series'], loc=1)
plt.title('pupil time series, with measurement noise')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# %% [raw]
# Let's create a regressor separately for every type of event. In our case, we want to separately model (predict) a response every time a stimulus was presented on the left side of the screen, and model (predict) a response every time a stimulus was presented on the rights side of the screen:

# %%
duration = 60 # in seconds
times_l = np.array([5,15,16,25])
times_r = np.array([35,45,46,55])
regr_l = np.zeros(duration * sample_rate)
regr_r = np.zeros(duration * sample_rate)
for i in times_l:
    regr_l[i*sample_rate] = 1
for i in times_r:
    regr_r[i*sample_rate] = 1

regr_l_convolved = (sp.convolve(regr_l, IRF, 'full'))[:-(IRF.shape[0]-1)]
regr_r_convolved = (sp.convolve(regr_r, IRF, 'full'))[:-(IRF.shape[0]-1)]

fig = plt.figure()
plt.plot(timepoints, regr_l_convolved, color='r')
plt.plot(timepoints, regr_r_convolved, color='g')
plt.legend(['predicted responses left', 'predicted response right'], loc=1)
plt.title('regressors')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# %% [raw]
# Now, per regressor we want to find one scalar value (the "beta") that we can use to scale the regressor with such that it best describes the measured data.
#
# In the GLM, with a procedure called "multiple regression" we do this for all regressors in our design matrix at the same time:

# %%
# make design matrix:
designMatrix = np.vstack((regr_l_convolved, regr_r_convolved))

# plot design matrix:
fig = plt.figure(figsize=(2,2))
plt.imshow(designMatrix.T)
plt.xticks([0,1])
plt.title('design matrix')
plt.xlabel('nr samples')
plt.ylabel('length run')

# deconvolution:
designMatrix = np.mat(designMatrix).T
betas = ((designMatrix.T * designMatrix).I * designMatrix.T) * np.mat(convolved_signal_noise).T
betas = np.array(betas)

print betas
# Out:
# [[ 0.99887623]
#  [ 0.20968331]]

# %%
# make design matrix:
designMatrix = np.vstack((regr_l_convolved, regr_r_convolved))

# plot design matrix:
fig = plt.figure(figsize=(2,2))
plt.imshow(designMatrix.T)
plt.xticks([0,1])
plt.title('design matrix')
plt.xlabel('nr samples')
plt.ylabel('length run')

# multiple regression:
designMatrix = np.mat(designMatrix).T
betas = ((designMatrix.T * designMatrix).I * designMatrix.T) * np.mat(convolved_signal_noise).T
betas = np.array(betas)

print betas
# Out:
# [[ 0.99887623]
#  [ 0.20968331]]

# %%
explained_signal = regr_l_convolved*betas[0] + regr_r_convolved*betas[1]
residuals = convolved_signal_noise - explained_signal

fig = plt.figure()
plt.plot(timepoints, explained_signal, color='b')
plt.legend(['predicted signal'], loc=1)
plt.title('predicted signal')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

fig = plt.figure()
plt.plot(timepoints, residuals, color='b')
plt.legend(['residuals'], loc=1)
plt.title('residuals')
plt.xlabel('time (s)')
plt.ylabel('a.u.')

# %%
print betas
fig = plt.figure()
ax = fig.add_subplot(111)
a = ax.imshow(betas.T, interpolation='nearest', vmin=0, vmax=1, cmap='YlOrRd')
ax.set_xticks([0,1])
ax.set_yticks([])
ax.set_xticklabels(['beta left', 'beta right'])
fig.colorbar(a, ticks=[-1, 0, 1], orientation='vertical', )
# Out:
# [[ 0.99887623]
#  [ 0.20968331]]
# <matplotlib.colorbar.Colorbar instance at 0x10d6f4f80>

# %%
x,y = np.mgrid[-2:2:20, 0:(2*math.pi):20]
f = exp(-x**2) * np.sin(y)
plt.contourf(f)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-cc318f592bdc> in <module>()
#       1 x,y = np.mgrid[-2:2:20, 0:(2*math.pi):20]
#       2 f = exp(-x**2) * np.sin(y)
# ----> 3 plt.contourf(f)
#       4 plt.show()
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/pyplot.pyc in contourf(*args, **kwargs)
#    2648         ax.hold(hold)
#    2649     try:
# -> 2650         ret = ax.contourf(*args, **kwargs)
#    2651         draw_if_interactive()
#    2652     finally:
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/axes.pyc in contourf(self, *args, **kwargs)
#    7981             self.cla()
#    7982         kwargs['filled'] = True
# -> 7983         return mcontour.QuadContourSet(self, *args, **kwargs)
#    7984     contourf.__doc__ = mcontour.QuadContourSet.contour_doc
#    7985
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1412         are described in QuadContourSet.contour_doc.
#    1413         """
# -> 1414         ContourSet.__init__(self, ax, *args, **kwargs)
#    1415
#    1416     def _process_args(self, *args, **kwargs):
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     858         self._transform = kwargs.get('transform', None)
#     859
# --> 860         self._process_args(*args, **kwargs)
#     861         self._process_levels()
#     862
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1425             self.zmax = args[0].zmax
#    1426         else:
# -> 1427             x, y, z = self._contour_args(args, kwargs)
#    1428
#    1429             _mask = ma.getmask(z)
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1486         if Nargs <= 2:
#    1487             z = ma.asarray(args[0], dtype=np.float64)
# -> 1488             x, y = self._initialize_x_y(z)
#    1489             args = args[1:]
#    1490         elif Nargs <= 4:
#
# /Users/jwdegee/ENV/lib/python2.7/site-packages/matplotlib/contour.pyc in _initialize_x_y(self, z)
#    1571         """
#    1572         if z.ndim != 2:
# -> 1573             raise TypeError("Input must be a 2D array.")
#    1574         else:
#    1575             Ny, Nx = z.shape
#
# TypeError: Input must be a 2D array.

# %%
2*math.pi
# Out:
# 6.283185307179586
